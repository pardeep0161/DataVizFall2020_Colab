# %% [markdown]
# <a href="https://colab.research.google.com/github/pardeep0161/DataVizFall2020_Colab/blob/master/Week_11_Mon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
elec_res_2020 = pd.read_csv("2020_US_County_Level_Presidential_Results.csv")
elec_res_past = pd.read_csv("2008_2016_US_County_Level_Presidential_Results.csv")

# %%
elec_res_2020
# Out:
#      state_name  county_fips  ...   per_dem  per_point_diff
# 0       Alabama         1001  ...  0.269547        0.445530
# 1       Alabama         1003  ...  0.223452        0.538905
# 2       Alabama         1005  ...  0.456345        0.079660
# 3       Alabama         1007  ...  0.207041        0.577249
# 4       Alabama         1009  ...  0.095670        0.800029
# ...         ...          ...  ...       ...             ...
# 3154    Wyoming        56037  ...  0.231791        0.507914
# 3155    Wyoming        56039  ...  0.670982       -0.375213
# 3156    Wyoming        56041  ...  0.169255        0.627979
# 3157    Wyoming        56043  ...  0.162263        0.646560
# 3158    Wyoming        56045  ...  0.101637        0.775551
#
# [3159 rows x 10 columns]

# %%
elec_res_past[elec_res_past["county"] == "Delta County"]
# Out:
#       fips_code        county  total_2008  ...  dem_2016  gop_2016  oth_2016
# 0         26041  Delta County       19064  ...      6431     11112       924
# 1234       8029  Delta County       15434  ...      4048     11584      1029
# 2469      48119  Delta County        2187  ...       400      1836        43
#
# [3 rows x 14 columns]

# %%
elec_res = elec_res_2020.merge(elec_res_past,left_on="county_fips",right_on="fips_code")

# %%
elec_res_agg = elec_res.groupby("state_name", as_index=False).sum()

# %%
elec_res.head()
# Out:
#   state_name  county_fips     county_name  ...  dem_2016  gop_2016  oth_2016
# 0    Alabama         1001  Autauga County  ...      5908     18110       643
# 1    Alabama         1003  Baldwin County  ...     18409     72780      2901
# 2    Alabama         1005  Barbour County  ...      4848      5431       111
# 3    Alabama         1007     Bibb County  ...      1874      6733       141
# 4    Alabama         1009   Blount County  ...      2150     22808       426
#
# [5 rows x 24 columns]

# %%
elec_res_agg_2020 = elec_res_agg[['state_name','votes_gop',	'votes_dem',	'total_votes']]

# %%
elec_res_agg_past = elec_res_agg[['state_name','total_2008',	'dem_2008',	'gop_2008',	'oth_2008',	'total_2012',	'dem_2012',	'gop_2012',	'oth_2012',	'total_2016',	'dem_2016',	'gop_2016',	'oth_2016']]

# %%
elec_res_agg_2020.to_csv("elec_res_agg_2020.csv",index=False)

# %%
elec_res_agg_past.to_csv("elec_res_agg_past.csv",index=False)
